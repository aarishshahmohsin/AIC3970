# %%
import numpy as np
import pandas as pd

# -------------------------
# Utility Functions
# -------------------------
def relu(Z):
    return np.maximum(0, Z)

def relu_derivative(Z):
    return (Z > 0).astype(float)

def softmax(Z):
    # subtract max for numerical stability
    expZ = np.exp(Z - np.max(Z, axis=1, keepdims=True))
    return expZ / np.sum(expZ, axis=1, keepdims=True)

def mse_loss(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

def cross_entropy_loss(y_true, y_pred):
    eps = 1e-15
    # Clip probabilities for numerical stability.
    y_pred_clipped = np.clip(y_pred, eps, 1 - eps)
    return -np.mean(np.sum(y_true * np.log(y_pred_clipped), axis=1))

# -------------------------
# Neural Network Class
# -------------------------
class NeuralNetwork:
    def __init__(self, layer_sizes, loss_type='cross_entropy', dropout_prob=0.0, learning_rate=0.01, seed=None):
        """
        layer_sizes: list containing the number of neurons in each layer.
                     For example, for 3 hidden layers: [input_dim, h1, h2, h3, output_dim]
        loss_type: 'cross_entropy' or 'mse'
        dropout_prob: probability of dropping a neuron (applied in hidden layers)
        learning_rate: learning rate for gradient descent
        """
        self.layer_sizes = layer_sizes
        self.num_layers = len(layer_sizes) - 1  # number of weight layers
        self.loss_type = loss_type
        self.dropout_prob = dropout_prob
        self.learning_rate = learning_rate
        if seed is not None:
            np.random.seed(seed)
        self.params = {}
        # Initialize weights and biases (using He initialization for ReLU)
        for l in range(1, len(layer_sizes)):
            self.params['W' + str(l)] = np.random.randn(layer_sizes[l-1], layer_sizes[l]) * np.sqrt(2.0 / layer_sizes[l-1])
            self.params['b' + str(l)] = np.zeros((1, layer_sizes[l]))

    def forward(self, X, training=True):
        """
        Forward propagation through the network.
        Applies ReLU activation in hidden layers. For the output layer:
          - if using cross-entropy loss, applies softmax activation.
          - if using MSE loss, uses a linear activation.
        Also applies dropout in hidden layers during training.
        """
        caches = {}
        A = X
        caches['A0'] = X
        for l in range(1, self.num_layers + 1):
            W = self.params['W' + str(l)]
            b = self.params['b' + str(l)]
            Z = np.dot(A, W) + b
            caches['Z' + str(l)] = Z
            if l != self.num_layers:  # hidden layers
                A = relu(Z)
                if training and self.dropout_prob > 0:
                    # create dropout mask: neurons with value 0 are dropped
                    D = (np.random.rand(*A.shape) > self.dropout_prob).astype(float)
                    A = A * D / (1 - self.dropout_prob)  # scale activations to maintain expectation
                    caches['D' + str(l)] = D
            else:
                # output layer activation depends on loss function choice
                if self.loss_type == 'cross_entropy':
                    A = softmax(Z)
                else:
                    A = Z  # linear activation for MSE
            caches['A' + str(l)] = A
        return A, caches

    def compute_loss(self, y_true, y_pred):
        if self.loss_type == 'cross_entropy':
            return cross_entropy_loss(y_true, y_pred)
        else:
            return mse_loss(y_true, y_pred)

    def backward(self, X, y, caches):
        """
        Backpropagation through the network.
        Computes gradients for weights and biases.
        """
        grads = {}
        m = X.shape[0]
        L = self.num_layers
        A_final = caches['A' + str(L)]
        # Derivative at output layer:
        if self.loss_type == 'cross_entropy':
            dZ = A_final - y  # derivative for softmax + cross entropy
        else:
            dZ = 2 * (A_final - y) / m  # derivative for MSE with linear output

        for l in range(L, 0, -1):
            A_prev = caches['A' + str(l-1)]
            W = self.params['W' + str(l)]
            dW = np.dot(A_prev.T, dZ)
            db = np.sum(dZ, axis=0, keepdims=True)
            grads['dW' + str(l)] = dW
            grads['db' + str(l)] = db
            if l > 1:  # no need to propagate for input layer
                dA_prev = np.dot(dZ, W.T)
                # If dropout was applied in the previous layer, use the same mask for backprop.
                if self.dropout_prob > 0 and ('D' + str(l-1)) in caches:
                    dA_prev = dA_prev * caches['D' + str(l-1)] / (1 - self.dropout_prob)
                dZ = dA_prev * relu_derivative(caches['Z' + str(l-1)])
        return grads

    def update_params(self, grads):
        """Update weights and biases using gradient descent."""
        for l in range(1, self.num_layers + 1):
            self.params['W' + str(l)] -= self.learning_rate * grads['dW' + str(l)]
            self.params['b' + str(l)] -= self.learning_rate * grads['db' + str(l)]

    def train(self, X_train, y_train, X_val, y_val, batch_size, max_epochs=200, patience=10, verbose=False):
        """
        Trains the network using either stochastic (batch_size=1) or mini-batch gradient descent.
        Early stopping is applied based on validation loss.
        Returns the training history and the epoch number with the best validation loss.
        """
        best_val_loss = np.inf
        best_epoch = 0
        best_params = None
        n_train = X_train.shape[0]
        history = {'train_loss': [], 'val_loss': []}

        for epoch in range(1, max_epochs + 1):
            # Shuffle the training data
            indices = np.arange(n_train)
            np.random.shuffle(indices)
            X_train = X_train[indices]
            y_train = y_train[indices]
            epoch_loss = 0
            num_batches = int(np.ceil(n_train / batch_size))
            for i in range(num_batches):
                start = i * batch_size
                end = min(start + batch_size, n_train)
                X_batch = X_train[start:end]
                y_batch = y_train[start:end]
                # Forward propagation on the batch
                y_pred, caches = self.forward(X_batch, training=True)
                loss = self.compute_loss(y_batch, y_pred)
                epoch_loss += loss
                # Backpropagation
                grads = self.backward(X_batch, y_batch, caches)
                self.update_params(grads)
            epoch_loss /= num_batches

            # Compute validation loss (without dropout)
            y_val_pred, _ = self.forward(X_val, training=False)
            val_loss = self.compute_loss(y_val, y_val_pred)
            history['train_loss'].append(epoch_loss)
            history['val_loss'].append(val_loss)
            if verbose:
                print(f"Epoch {epoch:3d}: Train Loss = {epoch_loss:.4f}, Val Loss = {val_loss:.4f}")

            # Early stopping check
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_epoch = epoch
                best_params = {key: val.copy() for key, val in self.params.items()}
            elif epoch - best_epoch >= patience:
                if verbose:
                    print(f"Early stopping at epoch {epoch}. Best epoch was {best_epoch}")
                break

        # Restore best parameters
        self.params = best_params
        return history, best_epoch

    def predict(self, X):
        """
        Returns the predicted class labels.
        (For regression with MSE, we assume one-hot encoded targets and use argmax.)
        """
        y_pred, _ = self.forward(X, training=False)
        return np.argmax(y_pred, axis=1)

# -------------------------
# Data Preprocessing
# -------------------------
# Load dataset (adjust the file path if necessary)
data = pd.read_csv("./obesity_data.csv")

# Assume that all columns except the last are features and the last column is the label.
features = data.iloc[:, :-1].values
labels = data.iloc[:, -1].values

# Convert labels to numerical values and then to one-hot encoding.
# (If labels are already numeric, this step may be simplified.)
classes, labels_encoded = np.unique(labels, return_inverse=True)
num_classes = len(classes)
y_onehot = np.eye(num_classes)[labels_encoded]

numerical_features = data.select_dtypes(include=np.number).iloc[:, :-1].values # Select numerical features only, excluding the label column
categorical_features = data.select_dtypes(exclude=np.number).iloc[:, :-1] # Select categorical features only, excluding the label column

# Standardize features (zero mean, unit variance)
X_num = numerical_features.astype(float)
X_num_mean = X_num.mean(axis=0)
X_num_std = X_num.std(axis=0) + 1e-8
X_num = (X_num - X_num_mean) / X_num_std

# One-hot encode categorical features
X_cat = pd.get_dummies(categorical_features).values  # Use pandas get_dummies to one-hot encode

# Combine standardized numerical features and one-hot encoded categorical features
X = np.concatenate([X_num, X_cat], axis=1)

# Split data into training and validation sets (80/20 split)
indices = np.arange(X.shape[0])
np.random.shuffle(indices)
train_size = int(0.8 * X.shape[0])
train_idx = indices[:train_size]
val_idx = indices[train_size:]
X_train, X_val = X[train_idx], X[val_idx]
y_train, y_val = y_onehot[train_idx], y_onehot[val_idx]

# -------------------------
# Experiment Settings
# -------------------------
# Define two architectures:
# N1: 3 hidden layers, e.g., [input_dim, 64, 32, 16, output_dim]
# N2: 4 hidden layers, e.g., [input_dim, 64, 32, 16, 8, output_dim]
input_dim = X_train.shape[1]
output_dim = num_classes

architecture_N1 = [input_dim, 64, 32, 16, output_dim]
architecture_N2 = [input_dim, 64, 32, 16, 8, output_dim]

# Settings for dropout, learning rate, and training
dropout_prob = 0.2
learning_rate = 0.01
max_epochs = 200
patience = 10

# We will run experiments for both loss functions and both gradient descent strategies:
loss_options = ['cross_entropy', 'mse']
batch_options = {
    'stochastic': 1,    # stochastic gradient descent (one sample at a time)
    'mini-batch': 40    # mini-batch gradient descent with batch size 40
}

# -------------------------
# Run Experiments
# -------------------------
results = {}

for net_name, arch in zip(["N1 (3 hidden layers)", "N2 (4 hidden layers)"], [architecture_N1, architecture_N2]):
    for loss in loss_options:
        for grad_desc, batch_size in batch_options.items():
            exp_name = f"{net_name} | Loss: {loss} | {grad_desc}"
            print("Running experiment:", exp_name)
            nn = NeuralNetwork(layer_sizes=arch, loss_type=loss, dropout_prob=dropout_prob,
                               learning_rate=learning_rate, seed=42)
            history, best_epoch = nn.train(X_train, y_train, X_val, y_val, batch_size=batch_size,
                                           max_epochs=max_epochs, patience=patience, verbose=True)
            y_pred = nn.predict(X_val)
            y_true = np.argmax(y_val, axis=1)
            accuracy = np.mean(y_pred == y_true)
            results[exp_name] = {"Best Epoch": best_epoch,
                                 "Validation Accuracy": accuracy,
                                 "Final Train Loss": history['train_loss'][-1],
                                 "Final Val Loss": history['val_loss'][-1]}
            print(f"Experiment: {exp_name}")
            print(f"  Best Epoch: {best_epoch}")
            print(f"  Final Validation Loss: {history['val_loss'][-1]:.4f}")
            print(f"  Validation Accuracy: {accuracy*100:.2f}%")
            print("-" * 50)

# -------------------------
# Summary of Results
# -------------------------
print("\nSummary of all experiments:")
for exp_name, res in results.items():
    print(exp_name)
    print(f"  Best Epoch: {res['Best Epoch']}")
    print(f"  Final Validation Loss: {res['Final Val Loss']:.4f}")
    print(f"  Validation Accuracy: {res['Validation Accuracy']*100:.2f}%")
    print("-" * 50)
# Out:
# Running experiment: N1 (3 hidden layers) | Loss: cross_entropy | stochastic
# Epoch   1: Train Loss = 0.9258, Val Loss = 0.4753
# Epoch   2: Train Loss = 0.6058, Val Loss = 0.4299
# Epoch   3: Train Loss = 0.5278, Val Loss = 0.2991
# Epoch   4: Train Loss = 0.4416, Val Loss = 0.2482
# Epoch   5: Train Loss = 0.4443, Val Loss = 0.2464
# Epoch   6: Train Loss = 0.4107, Val Loss = 0.2088
# Epoch   7: Train Loss = 0.3522, Val Loss = 0.3344
# Epoch   8: Train Loss = 0.3340, Val Loss = 0.1403
# Epoch   9: Train Loss = 0.3229, Val Loss = 0.1511
# Epoch  10: Train Loss = 0.3053, Val Loss = 0.1416
# Epoch  11: Train Loss = 0.2740, Val Loss = 0.1715
# Epoch  12: Train Loss = 0.2620, Val Loss = 0.1753
# Epoch  13: Train Loss = 0.2687, Val Loss = 0.1273
# Epoch  14: Train Loss = 0.2397, Val Loss = 0.1682
# Epoch  15: Train Loss = 0.2547, Val Loss = 0.2205
# Epoch  16: Train Loss = 0.2322, Val Loss = 0.1037
# Epoch  17: Train Loss = 0.2057, Val Loss = 0.1024
# Epoch  18: Train Loss = 0.2417, Val Loss = 0.1311
# Epoch  19: Train Loss = 0.2295, Val Loss = 0.1072
# Epoch  20: Train Loss = 0.2096, Val Loss = 0.1065
# Epoch  21: Train Loss = 0.1827, Val Loss = 0.0788
# Epoch  22: Train Loss = 0.1883, Val Loss = 0.1165
# Epoch  23: Train Loss = 0.1682, Val Loss = 0.0785
# Epoch  24: Train Loss = 0.1913, Val Loss = 0.1630
# Epoch  25: Train Loss = 0.1651, Val Loss = 0.0931
# Epoch  26: Train Loss = 0.1364, Val Loss = 0.1563
# Epoch  27: Train Loss = 0.1907, Val Loss = 0.0923
# Epoch  28: Train Loss = 0.1807, Val Loss = 0.1289
# Epoch  29: Train Loss = 0.1687, Val Loss = 0.0966
# Epoch  30: Train Loss = 0.1647, Val Loss = 0.0717
# Epoch  31: Train Loss = 0.1340, Val Loss = 0.0593
# Epoch  32: Train Loss = 0.1646, Val Loss = 0.1190
# Epoch  33: Train Loss = 0.1213, Val Loss = 0.0618
# Epoch  34: Train Loss = 0.1316, Val Loss = 0.0702
# Epoch  35: Train Loss = 0.1248, Val Loss = 0.0829
# Epoch  36: Train Loss = 0.1554, Val Loss = 0.0649
# Epoch  37: Train Loss = 0.1506, Val Loss = 0.0845
# Epoch  38: Train Loss = 0.1134, Val Loss = 0.0630
# Epoch  39: Train Loss = 0.1046, Val Loss = 0.0814
# Epoch  40: Train Loss = 0.1587, Val Loss = 0.0660
# Epoch  41: Train Loss = 0.0961, Val Loss = 0.0335
# Epoch  42: Train Loss = 0.1263, Val Loss = 0.0707
# Epoch  43: Train Loss = 0.1016, Val Loss = 0.0606
# Epoch  44: Train Loss = 0.1317, Val Loss = 0.1588
# Epoch  45: Train Loss = 0.1644, Val Loss = 0.0626
# Epoch  46: Train Loss = 0.1283, Val Loss = 0.0802
# Epoch  47: Train Loss = 0.1423, Val Loss = 0.0713
# Epoch  48: Train Loss = 0.1210, Val Loss = 0.1338
# Epoch  49: Train Loss = 0.1570, Val Loss = 0.0692
# Epoch  50: Train Loss = 0.1148, Val Loss = 0.0577
# Epoch  51: Train Loss = 0.1171, Val Loss = 0.0719
# Early stopping at epoch 51. Best epoch was 41
# Experiment: N1 (3 hidden layers) | Loss: cross_entropy | stochastic
#   Best Epoch: 41
#   Final Validation Loss: 0.0719
#   Validation Accuracy: 98.00%
# --------------------------------------------------
# Running experiment: N1 (3 hidden layers) | Loss: cross_entropy | mini-batch
# Epoch   1: Train Loss = 1.1738, Val Loss = 0.5815
# Epoch   2: Train Loss = 0.7571, Val Loss = 0.4977
# Epoch   3: Train Loss = 0.6086, Val Loss = 0.4223
# Epoch   4: Train Loss = 0.5452, Val Loss = 0.3284
# Epoch   5: Train Loss = 0.4854, Val Loss = 0.3005
# Epoch   6: Train Loss = 0.4176, Val Loss = 0.2477
# Epoch   7: Train Loss = 0.3595, Val Loss = 0.3139
# Epoch   8: Train Loss = 0.4860, Val Loss = 0.2095
# Epoch   9: Train Loss = 0.3755, Val Loss = 0.2113
# Epoch  10: Train Loss = 0.3557, Val Loss = 0.2877
# Epoch  11: Train Loss = 0.2958, Val Loss = 0.1861
# Epoch  12: Train Loss = 0.2532, Val Loss = 0.1832
# Epoch  13: Train Loss = 0.3094, Val Loss = 0.1429
# Epoch  14: Train Loss = 0.3034, Val Loss = 0.1651
# Epoch  15: Train Loss = 0.2501, Val Loss = 0.1626
# Epoch  16: Train Loss = 0.2592, Val Loss = 0.1189
# Epoch  17: Train Loss = 0.2406, Val Loss = 0.1077
# Epoch  18: Train Loss = 0.2076, Val Loss = 0.1886
# Epoch  19: Train Loss = 0.2710, Val Loss = 0.1631
# Epoch  20: Train Loss = 0.2225, Val Loss = 0.1321
# Epoch  21: Train Loss = 0.2361, Val Loss = 0.1175
# Epoch  22: Train Loss = 0.2048, Val Loss = 0.0963
# Epoch  23: Train Loss = 0.1983, Val Loss = 0.1227
# Epoch  24: Train Loss = 0.1914, Val Loss = 0.1750
# Epoch  25: Train Loss = 0.2142, Val Loss = 0.1585
# Epoch  26: Train Loss = 0.1794, Val Loss = 0.2814
# Epoch  27: Train Loss = 0.1818, Val Loss = 0.1282
# Epoch  28: Train Loss = 0.1669, Val Loss = 0.3059
# Epoch  29: Train Loss = 0.2088, Val Loss = 0.1058
# Epoch  30: Train Loss = 0.1730, Val Loss = 0.1172
# Epoch  31: Train Loss = 0.1836, Val Loss = 0.2044
# Epoch  32: Train Loss = 0.1791, Val Loss = 0.1325
# Early stopping at epoch 32. Best epoch was 22
# Experiment: N1 (3 hidden layers) | Loss: cross_entropy | mini-batch
#   Best Epoch: 22
#   Final Validation Loss: 0.1325
#   Validation Accuracy: 96.00%
# --------------------------------------------------
# Running experiment: N1 (3 hidden layers) | Loss: mse | stochastic
# Epoch   1: Train Loss = 0.2095, Val Loss = 0.1786
# Epoch   2: Train Loss = 0.1723, Val Loss = 0.1425
# Epoch   3: Train Loss = 0.1581, Val Loss = 0.1193
# Epoch   4: Train Loss = 0.1495, Val Loss = 0.1288
# Epoch   5: Train Loss = 0.1430, Val Loss = 0.1195
# Epoch   6: Train Loss = 0.1517, Val Loss = 0.1564
# Epoch   7: Train Loss = 0.1594, Val Loss = 0.1543
# Epoch   8: Train Loss = 0.1557, Val Loss = 0.1400
# Epoch   9: Train Loss = 0.1464, Val Loss = 0.1041
# Epoch  10: Train Loss = 0.1302, Val Loss = 0.1010
# Epoch  11: Train Loss = 0.1164, Val Loss = 0.0767
# Epoch  12: Train Loss = 0.1139, Val Loss = 0.1042
# Epoch  13: Train Loss = 0.1091, Val Loss = 0.0726
# Epoch  14: Train Loss = 0.1052, Val Loss = 0.0741
# Epoch  15: Train Loss = 0.1186, Val Loss = 0.0970
# Epoch  16: Train Loss = 0.1170, Val Loss = 0.0895
# Epoch  17: Train Loss = 0.1092, Val Loss = 0.0877
# Epoch  18: Train Loss = 0.1067, Val Loss = 0.0817
# Epoch  19: Train Loss = 0.1112, Val Loss = 0.0858
# Epoch  20: Train Loss = 0.1071, Val Loss = 0.0858
# Epoch  21: Train Loss = 0.1031, Val Loss = 0.0809
# Epoch  22: Train Loss = 0.0887, Val Loss = 0.0562
# Epoch  23: Train Loss = 0.0984, Val Loss = 0.0809
# Epoch  24: Train Loss = 0.1027, Val Loss = 0.0809
# Epoch  25: Train Loss = 0.1036, Val Loss = 0.0702
# Epoch  26: Train Loss = 0.0882, Val Loss = 0.0568
# Epoch  27: Train Loss = 0.1007, Val Loss = 0.0815
# Epoch  28: Train Loss = 0.0985, Val Loss = 0.0795
# Epoch  29: Train Loss = 0.0943, Val Loss = 0.0750
# Epoch  30: Train Loss = 0.0937, Val Loss = 0.0725
# Epoch  31: Train Loss = 0.0912, Val Loss = 0.0738
# Epoch  32: Train Loss = 0.0935, Val Loss = 0.0759
# Early stopping at epoch 32. Best epoch was 22
# Experiment: N1 (3 hidden layers) | Loss: mse | stochastic
#   Best Epoch: 22
#   Final Validation Loss: 0.0759
#   Validation Accuracy: 90.00%
# --------------------------------------------------
# Running experiment: N1 (3 hidden layers) | Loss: mse | mini-batch
# Epoch   1: Train Loss = 0.8443, Val Loss = 0.2182
# Epoch   2: Train Loss = 0.2605, Val Loss = 0.1826
# Epoch   3: Train Loss = 0.2079, Val Loss = 0.1709
# Epoch   4: Train Loss = 0.1977, Val Loss = 0.1688
# Epoch   5: Train Loss = 0.1885, Val Loss = 0.1645
# Epoch   6: Train Loss = 0.1795, Val Loss = 0.1613
# Epoch   7: Train Loss = 0.1844, Val Loss = 0.1601
# Epoch   8: Train Loss = 0.1764, Val Loss = 0.1591
# Epoch   9: Train Loss = 0.1749, Val Loss = 0.1563
# Epoch 197: Train Loss = 0.0834, Val Loss = 0.0553
# Epoch 198: Train Loss = 0.0843, Val Loss = 0.0560
# Epoch 199: Train Loss = 0.0853, Val Loss = 0.0523
# Epoch 200: Train Loss = 0.0835, Val Loss = 0.0536
# Experiment: N1 (3 hidden layers) | Loss: mse | mini-batch
#   Best Epoch: 196
#   Final Validation Loss: 0.0536
#   Validation Accuracy: 94.50%
# --------------------------------------------------
# Running experiment: N2 (4 hidden layers) | Loss: cross_entropy | stochastic
# Epoch   1: Train Loss = 1.1134, Val Loss = 0.6112
# Epoch   2: Train Loss = 0.7453, Val Loss = 0.4693
# Epoch   3: Train Loss = 0.6193, Val Loss = 0.3842
# Epoch   4: Train Loss = 0.5634, Val Loss = 0.3656
# Epoch   5: Train Loss = 0.5088, Val Loss = 0.2988
# Epoch   6: Train Loss = 0.5043, Val Loss = 0.3037
# Epoch   7: Train Loss = 0.4402, Val Loss = 0.3469
# Epoch   8: Train Loss = 0.4977, Val Loss = 0.3387
# Epoch   9: Train Loss = 0.4219, Val Loss = 0.2684
# Epoch  10: Train Loss = 0.3956, Val Loss = 0.2080
# Epoch  11: Train Loss = 0.4368, Val Loss = 0.2158
# Epoch  12: Train Loss = 0.4006, Val Loss = 0.2062
# Epoch  13: Train Loss = 0.3758, Val Loss = 0.1842
# Epoch  14: Train Loss = 0.3340, Val Loss = 0.1667
# Epoch  15: Train Loss = 0.3557, Val Loss = 0.3325
# Epoch  16: Train Loss = 0.3468, Val Loss = 0.1685
# Epoch  17: Train Loss = 0.3276, Val Loss = 0.1619
# Epoch  18: Train Loss = 0.3596, Val Loss = 0.1607
# Epoch  19: Train Loss = 0.3283, Val Loss = 0.1682
# Epoch  20: Train Loss = 0.2901, Val Loss = 0.1872
# Epoch  21: Train Loss = 0.2573, Val Loss = 0.1192
# Epoch  22: Train Loss = 0.3064, Val Loss = 0.1180
# Epoch  23: Train Loss = 0.3026, Val Loss = 0.1264
# Epoch  24: Train Loss = 0.2182, Val Loss = 0.1379
# Epoch  25: Train Loss = 0.2786, Val Loss = 0.1453
# Epoch  26: Train Loss = 0.2408, Val Loss = 0.1237
# Epoch  27: Train Loss = 0.2741, Val Loss = 0.1050
# Epoch  28: Train Loss = 0.2671, Val Loss = 0.2064
# Epoch  29: Train Loss = 0.2134, Val Loss = 0.1310
# Epoch  30: Train Loss = 0.2544, Val Loss = 0.1508
# Epoch  31: Train Loss = 0.2324, Val Loss = 0.1308
# Epoch  32: Train Loss = 0.2138, Val Loss = 0.1780
# Epoch  33: Train Loss = 0.2210, Val Loss = 0.1050
# Epoch  34: Train Loss = 0.2542, Val Loss = 0.0973
# Epoch  35: Train Loss = 0.2575, Val Loss = 0.1023
# Epoch  36: Train Loss = 0.2017, Val Loss = 0.0857
# Epoch  37: Train Loss = 0.2369, Val Loss = 0.1721
# Epoch  38: Train Loss = 0.2196, Val Loss = 0.0941
# Epoch  39: Train Loss = 0.2213, Val Loss = 0.0801
# Epoch  40: Train Loss = 0.1907, Val Loss = 0.0883
# Epoch  41: Train Loss = 0.1894, Val Loss = 0.1380
# Epoch  42: Train Loss = 0.2641, Val Loss = 0.1034
# Epoch  43: Train Loss = 0.1889, Val Loss = 0.1255
# Epoch  44: Train Loss = 0.1993, Val Loss = 0.1570
# Epoch  45: Train Loss = 0.2087, Val Loss = 0.1129
# Epoch  46: Train Loss = 0.2553, Val Loss = 0.0831
# Epoch  47: Train Loss = 0.2032, Val Loss = 0.1089
# Epoch  48: Train Loss = 0.1811, Val Loss = 0.0521
# Epoch  49: Train Loss = 0.1592, Val Loss = 0.1226
# Epoch  50: Train Loss = 0.2323, Val Loss = 0.1003
# Epoch  51: Train Loss = 0.1738, Val Loss = 0.0859
# Epoch  52: Train Loss = 0.1381, Val Loss = 0.0724
# Epoch  53: Train Loss = 0.1716, Val Loss = 0.0578
# Epoch  54: Train Loss = 0.1845, Val Loss = 0.0847
# Epoch  55: Train Loss = 0.2373, Val Loss = 0.1310
# Epoch  56: Train Loss = 0.2062, Val Loss = 0.0840
# Epoch  57: Train Loss = 0.1886, Val Loss = 0.0802
# Epoch  58: Train Loss = 0.2027, Val Loss = 0.0582
# Early stopping at epoch 58. Best epoch was 48
# Experiment: N2 (4 hidden layers) | Loss: cross_entropy | stochastic
#   Best Epoch: 48
#   Final Validation Loss: 0.0582
#   Validation Accuracy: 99.50%
# --------------------------------------------------
# Running experiment: N2 (4 hidden layers) | Loss: cross_entropy | mini-batch
# Epoch   1: Train Loss = 1.1867, Val Loss = 0.7798
# Epoch   2: Train Loss = 0.9018, Val Loss = 0.6008
# Epoch   3: Train Loss = 0.7990, Val Loss = 0.4908
# Epoch   4: Train Loss = 0.7136, Val Loss = 0.4287
# Epoch   5: Train Loss = 0.6471, Val Loss = 0.3456
# Epoch   6: Train Loss = 0.5767, Val Loss = 0.3345
# Epoch   7: Train Loss = 0.5704, Val Loss = 0.3348
# Epoch   8: Train Loss = 0.5054, Val Loss = 0.2143
# Epoch   9: Train Loss = 0.4414, Val Loss = 0.2862
# Epoch  10: Train Loss = 0.4649, Val Loss = 0.2619
# Epoch  11: Train Loss = 0.5358, Val Loss = 0.5776
# Epoch  12: Train Loss = 0.3812, Val Loss = 0.2035
# Epoch  13: Train Loss = 0.3667, Val Loss = 0.2259
# Epoch  14: Train Loss = 0.4048, Val Loss = 0.1569
# Epoch  15: Train Loss = 0.3347, Val Loss = 0.1482
# Epoch  16: Train Loss = 0.3494, Val Loss = 0.1651
# Epoch  17: Train Loss = 0.3389, Val Loss = 0.1540
# Epoch  18: Train Loss = 0.3337, Val Loss = 0.1546
# Epoch  19: Train Loss = 0.3026, Val Loss = 0.1350
# Epoch  20: Train Loss = 0.3417, Val Loss = 0.2361
# Epoch  21: Train Loss = 0.3831, Val Loss = 0.1227
# Epoch  22: Train Loss = 0.2829, Val Loss = 0.1317
# Epoch  23: Train Loss = 0.2993, Val Loss = 0.0971
# Epoch  24: Train Loss = 0.3086, Val Loss = 0.1503
# Epoch  25: Train Loss = 0.3290, Val Loss = 0.1504
# Epoch  26: Train Loss = 0.2945, Val Loss = 0.1121
# Epoch  27: Train Loss = 0.2917, Val Loss = 0.0996
# Epoch  28: Train Loss = 0.3300, Val Loss = 0.1523
# Epoch  29: Train Loss = 0.2444, Val Loss = 0.0979
# Epoch  30: Train Loss = 0.2659, Val Loss = 0.1277
# Epoch  31: Train Loss = 0.2843, Val Loss = 0.1534
# Epoch  32: Train Loss = 0.2325, Val Loss = 0.1184
# Epoch  33: Train Loss = 0.2241, Val Loss = 0.1231
# Early stopping at epoch 33. Best epoch was 23
# Experiment: N2 (4 hidden layers) | Loss: cross_entropy | mini-batch
#   Best Epoch: 23
#   Final Validation Loss: 0.1231
#   Validation Accuracy: 98.00%
# --------------------------------------------------
# Running experiment: N2 (4 hidden layers) | Loss: mse | stochastic
# Epoch   1: Train Loss = 0.1997, Val Loss = 0.1775
# Epoch   2: Train Loss = 0.1805, Val Loss = 0.1753
# Epoch   3: Train Loss = 0.1703, Val Loss = 0.1630
# Epoch   4: Train Loss = 0.1680, Val Loss = 0.1666
# Epoch   5: Train Loss = 0.1732, Val Loss = 0.1773
# Epoch   6: Train Loss = 0.1682, Val Loss = 0.1580
# Epoch   7: Train Loss = 0.1644, Val Loss = 0.1525
# Epoch   8: Train Loss = 0.1607, Val Loss = 0.1477
# Epoch   9: Train Loss = 0.1586, Val Loss = 0.1417
# Epoch  10: Train Loss = 0.1529, Val Loss = 0.1340
# Epoch  11: Train Loss = 0.1521, Val Loss = 0.1308
# Epoch  12: Train Loss = 0.1477, Val Loss = 0.1245
# Epoch  13: Train Loss = 0.1489, Val Loss = 0.1248
# Epoch  14: Train Loss = 0.1499, Val Loss = 0.1284
# Epoch  15: Train Loss = 0.1462, Val Loss = 0.1239
# Epoch  16: Train Loss = 0.1395, Val Loss = 0.1245
# Epoch  17: Train Loss = 0.1387, Val Loss = 0.1128
# Epoch  18: Train Loss = 0.1426, Val Loss = 0.1169
# Epoch  19: Train Loss = 0.1433, Val Loss = 0.1150
# Epoch  20: Train Loss = 0.1408, Val Loss = 0.1235
# Epoch  21: Train Loss = 0.1388, Val Loss = 0.1120
# Epoch  22: Train Loss = 0.1356, Val Loss = 0.1077
# Epoch  23: Train Loss = 0.1289, Val Loss = 0.1103
# Epoch  24: Train Loss = 0.1271, Val Loss = 0.0930
# Epoch  25: Train Loss = 0.1251, Val Loss = 0.1022
# Epoch  26: Train Loss = 0.1247, Val Loss = 0.0934
# Epoch  27: Train Loss = 0.1227, Val Loss = 0.0921
# Epoch  28: Train Loss = 0.1152, Val Loss = 0.0821
# Epoch  29: Train Loss = 0.1164, Val Loss = 0.0866
# Epoch  30: Train Loss = 0.1146, Val Loss = 0.0948
# Epoch  31: Train Loss = 0.1106, Val Loss = 0.0895
# Epoch  32: Train Loss = 0.1061, Val Loss = 0.0865
# Epoch  33: Train Loss = 0.1060, Val Loss = 0.0821
# Epoch  34: Train Loss = 0.1093, Val Loss = 0.0854
# Epoch  35: Train Loss = 0.1062, Val Loss = 0.0840
# Epoch  36: Train Loss = 0.1078, Val Loss = 0.0908
# Epoch  37: Train Loss = 0.1061, Val Loss = 0.0805
# Epoch  38: Train Loss = 0.1045, Val Loss = 0.0859
# Epoch  39: Train Loss = 0.1068, Val Loss = 0.0853
# Epoch  40: Train Loss = 0.0994, Val Loss = 0.0805
# Epoch  41: Train Loss = 0.1011, Val Loss = 0.0833
# Epoch  42: Train Loss = 0.1056, Val Loss = 0.0833
# Epoch  43: Train Loss = 0.0998, Val Loss = 0.0802
# Epoch  44: Train Loss = 0.1048, Val Loss = 0.0801
# Epoch  45: Train Loss = 0.0992, Val Loss = 0.0833
# Epoch  46: Train Loss = 0.1040, Val Loss = 0.0831
# Epoch  47: Train Loss = 0.1026, Val Loss = 0.0857
# Epoch  48: Train Loss = 0.1019, Val Loss = 0.0837
# Epoch  49: Train Loss = 0.1031, Val Loss = 0.0804
# Epoch  50: Train Loss = 0.0986, Val Loss = 0.0814
# Epoch  51: Train Loss = 0.1024, Val Loss = 0.0803
# Epoch  52: Train Loss = 0.0981, Val Loss = 0.0778
# Epoch  53: Train Loss = 0.1018, Val Loss = 0.0826
# Epoch  54: Train Loss = 0.1019, Val Loss = 0.0822
# Epoch  55: Train Loss = 0.0973, Val Loss = 0.0779
# Epoch  56: Train Loss = 0.0977, Val Loss = 0.0829
# Epoch  57: Train Loss = 0.0993, Val Loss = 0.0785
# Epoch  58: Train Loss = 0.0954, Val Loss = 0.0797
# Epoch  59: Train Loss = 0.1050, Val Loss = 0.0802
# Epoch  60: Train Loss = 0.1126, Val Loss = 0.0880
# Epoch  61: Train Loss = 0.1080, Val Loss = 0.0852
# Epoch  62: Train Loss = 0.1008, Val Loss = 0.0755
# Epoch  63: Train Loss = 0.1012, Val Loss = 0.0786
# Epoch  64: Train Loss = 0.1004, Val Loss = 0.0813
# Epoch  65: Train Loss = 0.0958, Val Loss = 0.0803
# Epoch  66: Train Loss = 0.0992, Val Loss = 0.0819
# Epoch  67: Train Loss = 0.0995, Val Loss = 0.0820
# Epoch  68: Train Loss = 0.0953, Val Loss = 0.0824
# Epoch  69: Train Loss = 0.0983, Val Loss = 0.0784
# Epoch  70: Train Loss = 0.0965, Val Loss = 0.0762
# Epoch  71: Train Loss = 0.0934, Val Loss = 0.0794
# Epoch  72: Train Loss = 0.0950, Val Loss = 0.0746
# Epoch  73: Train Loss = 0.0945, Val Loss = 0.0744
# Epoch  74: Train Loss = 0.0959, Val Loss = 0.0756
# Epoch  75: Train Loss = 0.0940, Val Loss = 0.0720
# Epoch  76: Train Loss = 0.0964, Val Loss = 0.0737
# Epoch  77: Train Loss = 0.0938, Val Loss = 0.0749
# Epoch  78: Train Loss = 0.0937, Val Loss = 0.0830
# Epoch  79: Train Loss = 0.0964, Val Loss = 0.0756
# Epoch  80: Train Loss = 0.0960, Val Loss = 0.0738
# Epoch  81: Train Loss = 0.0965, Val Loss = 0.0723
# Epoch  82: Train Loss = 0.0969, Val Loss = 0.0745
# Epoch  83: Train Loss = 0.1004, Val Loss = 0.0777
# Epoch  84: Train Loss = 0.0937, Val Loss = 0.0790
# Epoch  85: Train Loss = 0.0963, Val Loss = 0.0795
# Early stopping at epoch 85. Best epoch was 75
# Experiment: N2 (4 hidden layers) | Loss: mse | stochastic
#   Best Epoch: 75
#   Final Validation Loss: 0.0795
#   Validation Accuracy: 79.00%
# --------------------------------------------------
# Running experiment: N2 (4 hidden layers) | Loss: mse | mini-batch
# Epoch   1: Train Loss = 0.4736, Val Loss = 0.2190
# Epoch   2: Train Loss = 0.2342, Val Loss = 0.2031
# Epoch   3: Train Loss = 0.2063, Val Loss = 0.1910
# Epoch   4: Train Loss = 0.2033, Val Loss = 0.1846
# Epoch   5: Train Loss = 0.1940, Val Loss = 0.1808
# Epoch   6: Train Loss = 0.1885, Val Loss = 0.1772
# Epoch   7: Train Loss = 0.1840, Val Loss = 0.1753
# Epoch   8: Train Loss = 0.1841, Val Loss = 0.1743
# Epoch   9: Train Loss = 0.1855, Val Loss = 0.1738
# Epoch  10: Train Loss = 0.1888, Val Loss = 0.1731
# Epoch  11: Train Loss = 0.1786, Val Loss = 0.1725
# Epoch  12: Train Loss = 0.1790, Val Loss = 0.1721
# Epoch  13: Train Loss = 0.1772, Val Loss = 0.1712
# Epoch  14: Train Loss = 0.1757, Val Loss = 0.1705
# Epoch  15: Train Loss = 0.1797, Val Loss = 0.1708
# Epoch  16: Train Loss = 0.1760, Val Loss = 0.1703
# Epoch  17: Train Loss = 0.1740, Val Loss = 0.1694
# Epoch  18: Train Loss = 0.1733, Val Loss = 0.1685
# Epoch  19: Train Loss = 0.1727, Val Loss = 0.1677
# Epoch  20: Train Loss = 0.1715, Val Loss = 0.1671
# Epoch  21: Train Loss = 0.1731, Val Loss = 0.1661
# Epoch  22: Train Loss = 0.1700, Val Loss = 0.1653
# Epoch  23: Train Loss = 0.1732, Val Loss = 0.1651
# Epoch  24: Train Loss = 0.1715, Val Loss = 0.1644
# Epoch  25: Train Loss = 0.1693, Val Loss = 0.1636
# Epoch  26: Train Loss = 0.1669, Val Loss = 0.1634
# Epoch  27: Train Loss = 0.1680, Val Loss = 0.1629
# Epoch  28: Train Loss = 0.1674, Val Loss = 0.1623
# Epoch  29: Train Loss = 0.1676, Val Loss = 0.1620
# Epoch  30: Train Loss = 0.1670, Val Loss = 0.1607
# Epoch  31: Train Loss = 0.1676, Val Loss = 0.1608
# Epoch  32: Train Loss = 0.1678, Val Loss = 0.1600
# Epoch  33: Train Loss = 0.1652, Val Loss = 0.1589
# Epoch  34: Train Loss = 0.1674, Val Loss = 0.1591
# Epoch  35: Train Loss = 0.1676, Val Loss = 0.1588
# Epoch  36: Train Loss = 0.1636, Val Loss = 0.1585
# Epoch  37: Train Loss = 0.1656, Val Loss = 0.1582
# Epoch  38: Train Loss = 0.1657, Val Loss = 0.1585
# Epoch  39: Train Loss = 0.1626, Val Loss = 0.1579
# Epoch  40: Train Loss = 0.1650, Val Loss = 0.1581
# Epoch  41: Train Loss = 0.1633, Val Loss = 0.1573
# Epoch  42: Train Loss = 0.1648, Val Loss = 0.1573
# Epoch  43: Train Loss = 0.1618, Val Loss = 0.1567
# Epoch  44: Train Loss = 0.1625, Val Loss = 0.1567
# Epoch  45: Train Loss = 0.1623, Val Loss = 0.1564
# Epoch  46: Train Loss = 0.1622, Val Loss = 0.1565
# Epoch  47: Train Loss = 0.1622, Val Loss = 0.1563
# Epoch  48: Train Loss = 0.1623, Val Loss = 0.1558
# Epoch  49: Train Loss = 0.1619, Val Loss = 0.1564
# Epoch  50: Train Loss = 0.1643, Val Loss = 0.1557
# Epoch  51: Train Loss = 0.1624, Val Loss = 0.1554
# Epoch  52: Train Loss = 0.1597, Val Loss = 0.1560
# Epoch  53: Train Loss = 0.1619, Val Loss = 0.1559
# Epoch  54: Train Loss = 0.1615, Val Loss = 0.1555
# Epoch  55: Train Loss = 0.1615, Val Loss = 0.1552
# Epoch  56: Train Loss = 0.1608, Val Loss = 0.1544
# Epoch  57: Train Loss = 0.1592, Val Loss = 0.1538
# Epoch  58: Train Loss = 0.1607, Val Loss = 0.1540
# Epoch  59: Train Loss = 0.1636, Val Loss = 0.1546
# Epoch  60: Train Loss = 0.1604, Val Loss = 0.1543
# Epoch  61: Train Loss = 0.1617, Val Loss = 0.1545
# Epoch  62: Train Loss = 0.1610, Val Loss = 0.1547
# Epoch  63: Train Loss = 0.1602, Val Loss = 0.1553
# Epoch  64: Train Loss = 0.1611, Val Loss = 0.1547
# Epoch  65: Train Loss = 0.1617, Val Loss = 0.1540
# Epoch  66: Train Loss = 0.1603, Val Loss = 0.1541
# Epoch  67: Train Loss = 0.1597, Val Loss = 0.1535
# Epoch  68: Train Loss = 0.1600, Val Loss = 0.1531
# Epoch  69: Train Loss = 0.1585, Val Loss = 0.1533
# Epoch  70: Train Loss = 0.1603, Val Loss = 0.1530
# Epoch  71: Train Loss = 0.1571, Val Loss = 0.1538
# Epoch  72: Train Loss = 0.1561, Val Loss = 0.1528
# Epoch  73: Train Loss = 0.1603, Val Loss = 0.1533
# Epoch  74: Train Loss = 0.1569, Val Loss = 0.1534
# Epoch  75: Train Loss = 0.1599, Val Loss = 0.1529
# Epoch  76: Train Loss = 0.1587, Val Loss = 0.1522
# Epoch  77: Train Loss = 0.1600, Val Loss = 0.1522
# Epoch  78: Train Loss = 0.1600, Val Loss = 0.1523
# Epoch  79: Train Loss = 0.1594, Val Loss = 0.1521
# Epoch  80: Train Loss = 0.1573, Val Loss = 0.1517
# Epoch  81: Train Loss = 0.1585, Val Loss = 0.1515
# Epoch  82: Train Loss = 0.1583, Val Loss = 0.1510
# Epoch  83: Train Loss = 0.1575, Val Loss = 0.1511
# Epoch  84: Train Loss = 0.1581, Val Loss = 0.1504
# Epoch  85: Train Loss = 0.1602, Val Loss = 0.1508
# Epoch  86: Train Loss = 0.1580, Val Loss = 0.1497
# Epoch  87: Train Loss = 0.1585, Val Loss = 0.1502
# Epoch  88: Train Loss = 0.1581, Val Loss = 0.1501
# Epoch  89: Train Loss = 0.1582, Val Loss = 0.1503
# Epoch  90: Train Loss = 0.1595, Val Loss = 0.1504
# Epoch  91: Train Loss = 0.1574, Val Loss = 0.1509
# Epoch  92: Train Loss = 0.1588, Val Loss = 0.1493
# Epoch  93: Train Loss = 0.1587, Val Loss = 0.1501
# Epoch  94: Train Loss = 0.1592, Val Loss = 0.1490
# Epoch  95: Train Loss = 0.1599, Val Loss = 0.1495
# Epoch  96: Train Loss = 0.1549, Val Loss = 0.1492
# Epoch  97: Train Loss = 0.1574, Val Loss = 0.1495
# Epoch  98: Train Loss = 0.1580, Val Loss = 0.1491
# Epoch  99: Train Loss = 0.1575, Val Loss = 0.1492
# Epoch 100: Train Loss = 0.1567, Val Loss = 0.1484
# Epoch 101: Train Loss = 0.1564, Val Loss = 0.1481
# Epoch 102: Train Loss = 0.1552, Val Loss = 0.1466
# Epoch 103: Train Loss = 0.1569, Val Loss = 0.1471
# Epoch 104: Train Loss = 0.1557, Val Loss = 0.1475
# Epoch 105: Train Loss = 0.1569, Val Loss = 0.1475
# Epoch 106: Train Loss = 0.1564, Val Loss = 0.1467
# Epoch 107: Train Loss = 0.1539, Val Loss = 0.1458
# Epoch 108: Train Loss = 0.1532, Val Loss = 0.1454
# Epoch 109: Train Loss = 0.1547, Val Loss = 0.1466
# Epoch 110: Train Loss = 0.1532, Val Loss = 0.1461
# Epoch 111: Train Loss = 0.1543, Val Loss = 0.1441
# Epoch 112: Train Loss = 0.1520, Val Loss = 0.1444
# Epoch 113: Train Loss = 0.1533, Val Loss = 0.1426
# Epoch 114: Train Loss = 0.1533, Val Loss = 0.1413
# Epoch 115: Train Loss = 0.1511, Val Loss = 0.1417
# Epoch 116: Train Loss = 0.1533, Val Loss = 0.1426
# Epoch 117: Train Loss = 0.1557, Val Loss = 0.1411
# Epoch 118: Train Loss = 0.1523, Val Loss = 0.1407
# Epoch 119: Train Loss = 0.1522, Val Loss = 0.1402
# Epoch 120: Train Loss = 0.1516, Val Loss = 0.1386
# Epoch 121: Train Loss = 0.1507, Val Loss = 0.1371
# Epoch 122: Train Loss = 0.1522, Val Loss = 0.1385
# Epoch 123: Train Loss = 0.1490, Val Loss = 0.1377
# Epoch 124: Train Loss = 0.1503, Val Loss = 0.1365
# Epoch 125: Train Loss = 0.1492, Val Loss = 0.1356
# Epoch 126: Train Loss = 0.1476, Val Loss = 0.1349
# Epoch 127: Train Loss = 0.1502, Val Loss = 0.1365
# Epoch 128: Train Loss = 0.1478, Val Loss = 0.1354
# Epoch 129: Train Loss = 0.1482, Val Loss = 0.1338
# Epoch 130: Train Loss = 0.1482, Val Loss = 0.1325
# Epoch 131: Train Loss = 0.1450, Val Loss = 0.1346
# Epoch 132: Train Loss = 0.1461, Val Loss = 0.1321
# Epoch 133: Train Loss = 0.1479, Val Loss = 0.1307
# Epoch 134: Train Loss = 0.1470, Val Loss = 0.1309
# Epoch 135: Train Loss = 0.1472, Val Loss = 0.1307
# Epoch 136: Train Loss = 0.1440, Val Loss = 0.1289
# Epoch 137: Train Loss = 0.1486, Val Loss = 0.1280
# Epoch 138: Train Loss = 0.1427, Val Loss = 0.1279
# Epoch 139: Train Loss = 0.1462, Val Loss = 0.1270
# Epoch 140: Train Loss = 0.1464, Val Loss = 0.1269
# Epoch 141: Train Loss = 0.1409, Val Loss = 0.1262
# Epoch 142: Train Loss = 0.1465, Val Loss = 0.1254
# Epoch 143: Train Loss = 0.1418, Val Loss = 0.1248
# Epoch 144: Train Loss = 0.1454, Val Loss = 0.1254
# Epoch 145: Train Loss = 0.1452, Val Loss = 0.1246
# Epoch 146: Train Loss = 0.1438, Val Loss = 0.1237
# Epoch 147: Train Loss = 0.1434, Val Loss = 0.1236
# Epoch 148: Train Loss = 0.1419, Val Loss = 0.1222
# Epoch 149: Train Loss = 0.1419, Val Loss = 0.1223
# Epoch 150: Train Loss = 0.1434, Val Loss = 0.1216
# Epoch 151: Train Loss = 0.1360, Val Loss = 0.1206
# Epoch 152: Train Loss = 0.1478, Val Loss = 0.1208
# Epoch 153: Train Loss = 0.1425, Val Loss = 0.1207
# Epoch 154: Train Loss = 0.1412, Val Loss = 0.1201
# Epoch 155: Train Loss = 0.1433, Val Loss = 0.1194
# Epoch 156: Train Loss = 0.1383, Val Loss = 0.1197
# Epoch 157: Train Loss = 0.1349, Val Loss = 0.1182
# Epoch 158: Train Loss = 0.1395, Val Loss = 0.1177
# Epoch 159: Train Loss = 0.1416, Val Loss = 0.1177
# Epoch 160: Train Loss = 0.1372, Val Loss = 0.1174
# Epoch 161: Train Loss = 0.1372, Val Loss = 0.1161
# Epoch 162: Train Loss = 0.1371, Val Loss = 0.1168
# Epoch 163: Train Loss = 0.1370, Val Loss = 0.1154
# Epoch 164: Train Loss = 0.1339, Val Loss = 0.1156
# Epoch 165: Train Loss = 0.1410, Val Loss = 0.1160
# Epoch 166: Train Loss = 0.1392, Val Loss = 0.1153
# Epoch 167: Train Loss = 0.1282, Val Loss = 0.1134
# Epoch 168: Train Loss = 0.1377, Val Loss = 0.1132
# Epoch 169: Train Loss = 0.1335, Val Loss = 0.1134
# Epoch 170: Train Loss = 0.1357, Val Loss = 0.1118
# Epoch 171: Train Loss = 0.1342, Val Loss = 0.1075
# Epoch 172: Train Loss = 0.1334, Val Loss = 0.1060
# Epoch 173: Train Loss = 0.1281, Val Loss = 0.1011
# Epoch 174: Train Loss = 0.1306, Val Loss = 0.0983
# Epoch 175: Train Loss = 0.1225, Val Loss = 0.0951
# Epoch 176: Train Loss = 0.1343, Val Loss = 0.0931
# Epoch 177: Train Loss = 0.1292, Val Loss = 0.0924
# Epoch 178: Train Loss = 0.1274, Val Loss = 0.0902
# Epoch 179: Train Loss = 0.1229, Val Loss = 0.0896
# Epoch 180: Train Loss = 0.1267, Val Loss = 0.0901
# Epoch 181: Train Loss = 0.1249, Val Loss = 0.0877
# Epoch 182: Train Loss = 0.1229, Val Loss = 0.0860
# Epoch 183: Train Loss = 0.1216, Val Loss = 0.0850
# Epoch 184: Train Loss = 0.1180, Val Loss = 0.0844
# Epoch 185: Train Loss = 0.1281, Val Loss = 0.0845
# Epoch 186: Train Loss = 0.1191, Val Loss = 0.0841
# Epoch 187: Train Loss = 0.1210, Val Loss = 0.0844
# Epoch 188: Train Loss = 0.1164, Val Loss = 0.0831
# Epoch 189: Train Loss = 0.1186, Val Loss = 0.0831
# Epoch 190: Train Loss = 0.1223, Val Loss = 0.0834
# Epoch 191: Train Loss = 0.1205, Val Loss = 0.0845
# Epoch 192: Train Loss = 0.1298, Val Loss = 0.0851
# Epoch 193: Train Loss = 0.1158, Val Loss = 0.0823
# Epoch 194: Train Loss = 0.1149, Val Loss = 0.0824
# Epoch 195: Train Loss = 0.1212, Val Loss = 0.0830
# Epoch 196: Train Loss = 0.1207, Val Loss = 0.0833
# Epoch 197: Train Loss = 0.1179, Val Loss = 0.0826
# Epoch 198: Train Loss = 0.1207, Val Loss = 0.0818
# Epoch 199: Train Loss = 0.1199, Val Loss = 0.0821
# Epoch 200: Train Loss = 0.1193, Val Loss = 0.0813
# Experiment: N2 (4 hidden layers) | Loss: mse | mini-batch
#   Best Epoch: 200
#   Final Validation Loss: 0.0813
#   Validation Accuracy: 89.50%
# --------------------------------------------------
#
# Summary of all experiments:
# N1 (3 hidden layers) | Loss: cross_entropy | stochastic
#   Best Epoch: 41
#   Final Validation Loss: 0.0719
#   Validation Accuracy: 98.00%
# --------------------------------------------------
# N1 (3 hidden layers) | Loss: cross_entropy | mini-batch
#   Best Epoch: 22
#   Final Validation Loss: 0.1325
#   Validation Accuracy: 96.00%
# --------------------------------------------------
# N1 (3 hidden layers) | Loss: mse | stochastic
#   Best Epoch: 22
#   Final Validation Loss: 0.0759
#   Validation Accuracy: 90.00%
# --------------------------------------------------
# N1 (3 hidden layers) | Loss: mse | mini-batch
#   Best Epoch: 196
#   Final Validation Loss: 0.0536
#   Validation Accuracy: 94.50%
# --------------------------------------------------
# N2 (4 hidden layers) | Loss: cross_entropy | stochastic
#   Best Epoch: 48
#   Final Validation Loss: 0.0582
#   Validation Accuracy: 99.50%
# --------------------------------------------------
# N2 (4 hidden layers) | Loss: cross_entropy | mini-batch
#   Best Epoch: 23
#   Final Validation Loss: 0.1231
#   Validation Accuracy: 98.00%
# --------------------------------------------------
# N2 (4 hidden layers) | Loss: mse | stochastic
#   Best Epoch: 75
#   Final Validation Loss: 0.0795
#   Validation Accuracy: 79.00%
# --------------------------------------------------
# N2 (4 hidden layers) | Loss: mse | mini-batch
#   Best Epoch: 200
#   Final Validation Loss: 0.0813
#   Validation Accuracy: 89.50%
# --------------------------------------------------
